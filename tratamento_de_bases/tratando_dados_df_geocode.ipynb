# %%
# Importando df_geocode

import pandas as pd
import numpy as np

df_geocode = pd.read_csv('../bases_iniciais/df_geocode.csv')
df_geocode
# Out:
#      Unnamed: 0 Lab Id                                            Address  \
# 0             0   L152      3800 PLEASANT HILL RD STE 1, DULUTH, GA 30096
# 1             1   L520                    1614 N JAMES ST, ROME, NY 13440
# 2             2   L141     12911 120TH AVE NE STE D60, KIRKLAND, WA 98034
# 3             3   L524  5667 PEACHTREE DUNWOODY RD 250, ATLANTA, GA 30342
# 4             4   L545                 1204 IL HWY 164, OQUAWKA, IL 61469
# ..          ...    ...                                                ...
# 114         114   L886        1819 MARLTON PIKE W., CHERRY HILL, NJ 08002
# 115         115   L535                  603 SENECA ST 4, ONEIDA, NY 13421
# 116         116   L723           8052 STATE ROUTE 12, BARNEVELD, NY 13304
# 117         117   L163         3906 LILLIE AVE STE 3, DAVENPORT, IA 52806
# 118         118   L967        2700 GRANT ST. SUITE 107, CONCORD, CA 94520
#
#                     Location  Zipcode
# 0      34.000319,-84.1629724  30096.0
# ...

# %%
# Deletando coluna "Unnamed: 0"

df_geocode = df_geocode.drop(columns=['Unnamed: 0'])
df_geocode
# Out:
#     Lab Id                                            Address  \
# 0     L152      3800 PLEASANT HILL RD STE 1, DULUTH, GA 30096
# 1     L520                    1614 N JAMES ST, ROME, NY 13440
# 2     L141     12911 120TH AVE NE STE D60, KIRKLAND, WA 98034
# 3     L524  5667 PEACHTREE DUNWOODY RD 250, ATLANTA, GA 30342
# 4     L545                 1204 IL HWY 164, OQUAWKA, IL 61469
# ..     ...                                                ...
# 114   L886        1819 MARLTON PIKE W., CHERRY HILL, NJ 08002
# 115   L535                  603 SENECA ST 4, ONEIDA, NY 13421
# 116   L723           8052 STATE ROUTE 12, BARNEVELD, NY 13304
# 117   L163         3906 LILLIE AVE STE 3, DAVENPORT, IA 52806
# 118   L967        2700 GRANT ST. SUITE 107, CONCORD, CA 94520
#
#                     Location  Zipcode
# 0      34.000319,-84.1629724  30096.0
# 1     43.2311327,-75.4445363  13440.0
# 2    47.7162786,-122.1838152  98034.0
# 3     33.9093875,-84.3529096  30342.0
# ...

# %%
# checando valores nulos

df_geocode.isna().sum()
# Out:
# Lab Id      0
# Address     0
# Location    0
# Zipcode     1
# dtype: int64

# %%
# checando dado com valor nulo

df_geocode[df_geocode['Zipcode'].isna()]
# Out:
#    Lab Id      Address     Location  Zipcode
# 83     -2  Unavailable  Unavailable      NaN

# %%
# como o dado acima não tem sentido, vou retirar ele da base de dados

df_geocode = df_geocode.dropna()
df_geocode
# Out:
#     Lab Id                                            Address  \
# 0     L152      3800 PLEASANT HILL RD STE 1, DULUTH, GA 30096
# 1     L520                    1614 N JAMES ST, ROME, NY 13440
# 2     L141     12911 120TH AVE NE STE D60, KIRKLAND, WA 98034
# 3     L524  5667 PEACHTREE DUNWOODY RD 250, ATLANTA, GA 30342
# 4     L545                 1204 IL HWY 164, OQUAWKA, IL 61469
# ..     ...                                                ...
# 114   L886        1819 MARLTON PIKE W., CHERRY HILL, NJ 08002
# 115   L535                  603 SENECA ST 4, ONEIDA, NY 13421
# 116   L723           8052 STATE ROUTE 12, BARNEVELD, NY 13304
# 117   L163         3906 LILLIE AVE STE 3, DAVENPORT, IA 52806
# 118   L967        2700 GRANT ST. SUITE 107, CONCORD, CA 94520
#
#                     Location  Zipcode
# 0      34.000319,-84.1629724  30096.0
# 1     43.2311327,-75.4445363  13440.0
# 2    47.7162786,-122.1838152  98034.0
# 3     33.9093875,-84.3529096  30342.0
# ...

# %%
# checando se a linha foi excluída

df_geocode.isna().sum()
# Out:
# Lab Id      0
# Address     0
# Location    0
# Zipcode     0
# dtype: int64

# %%
# resetando index

df_geocode.reset_index(inplace=True, drop=True)
df_geocode
# Out:
#     Lab Id                                            Address  \
# 0     L152      3800 PLEASANT HILL RD STE 1, DULUTH, GA 30096
# 1     L520                    1614 N JAMES ST, ROME, NY 13440
# 2     L141     12911 120TH AVE NE STE D60, KIRKLAND, WA 98034
# 3     L524  5667 PEACHTREE DUNWOODY RD 250, ATLANTA, GA 30342
# 4     L545                 1204 IL HWY 164, OQUAWKA, IL 61469
# ..     ...                                                ...
# 113   L886        1819 MARLTON PIKE W., CHERRY HILL, NJ 08002
# 114   L535                  603 SENECA ST 4, ONEIDA, NY 13421
# 115   L723           8052 STATE ROUTE 12, BARNEVELD, NY 13304
# 116   L163         3906 LILLIE AVE STE 3, DAVENPORT, IA 52806
# 117   L967        2700 GRANT ST. SUITE 107, CONCORD, CA 94520
#
#                     Location  Zipcode
# 0      34.000319,-84.1629724  30096.0
# 1     43.2311327,-75.4445363  13440.0
# 2    47.7162786,-122.1838152  98034.0
# 3     33.9093875,-84.3529096  30342.0
# ...

# %%
# checando valores duplicados

df_geocode.duplicated().sum()
# Out:
# 0

# %%
# só para ter certeza

df_geocode['Lab Id'].duplicated().sum()
# Out:
# 0

# %%
# tornando nomes como padrão python

df_geocode = df_geocode.rename(columns = {'Lab Id':'lab_id', 'Address':'address', 'Location':'location', 'Zipcode': 'zipcode'})

# %%
# transformando zipcode em int e não float

df_geocode[['zipcode']] = df_geocode[['zipcode']].astype('int64')
df_geocode
# Out:
#     lab_id                                            address  \
# 0     L152      3800 PLEASANT HILL RD STE 1, DULUTH, GA 30096
# 1     L520                    1614 N JAMES ST, ROME, NY 13440
# 2     L141     12911 120TH AVE NE STE D60, KIRKLAND, WA 98034
# 3     L524  5667 PEACHTREE DUNWOODY RD 250, ATLANTA, GA 30342
# 4     L545                 1204 IL HWY 164, OQUAWKA, IL 61469
# ..     ...                                                ...
# 113   L886        1819 MARLTON PIKE W., CHERRY HILL, NJ 08002
# 114   L535                  603 SENECA ST 4, ONEIDA, NY 13421
# 115   L723           8052 STATE ROUTE 12, BARNEVELD, NY 13304
# 116   L163         3906 LILLIE AVE STE 3, DAVENPORT, IA 52806
# 117   L967        2700 GRANT ST. SUITE 107, CONCORD, CA 94520
#
#                     location  zipcode
# 0      34.000319,-84.1629724    30096
# 1     43.2311327,-75.4445363    13440
# 2    47.7162786,-122.1838152    98034
# 3     33.9093875,-84.3529096    30342
# ...

# %%
# avaliando incoerências

df_geocode.describe(include='all')
# Out:
#        lab_id                                        address  \
# count     118                                            118
# unique    118                                            118
# top      L152  3800 PLEASANT HILL RD STE 1, DULUTH, GA 30096
# freq        1                                              1
# mean      NaN                                            NaN
# std       NaN                                            NaN
# min       NaN                                            NaN
# 25%       NaN                                            NaN
# 50%       NaN                                            NaN
# 75%       NaN                                            NaN
# max       NaN                                            NaN
#
#                      location       zipcode
# count                     118    118.000000
# unique                    116           NaN
# top     33.451232,-94.0683805           NaN
# freq                        2           NaN
# ...

# %%
df_geocode[df_geocode.location.duplicated() == True]
# Out:
#    lab_id                                         address  \
# 65   L127    2920 KNIGHT ST STE 108, SHREVEPORT, LA 71105
# 67   L704  2305 CAMINO RAMON STE 110, SAN RAMON, CA 94583
#
#                    location  zipcode
# 65    33.451232,-94.0683805    71105
# 67  37.7754429,-121.9669886    94583

# %%
df_geocode[df_geocode.location == '33.451232,-94.0683805']
# Out:
#    lab_id                                        address  \
# 28   L503  3505 SUMMERHILL RD STE 3, TEXARKANA, TX 75503
# 65   L127   2920 KNIGHT ST STE 108, SHREVEPORT, LA 71105
#
#                  location  zipcode
# 28  33.451232,-94.0683805    75503
# 65  33.451232,-94.0683805    71105

# %%
df_geocode[df_geocode.location == '37.7754429,-121.9669886']
# Out:
#    lab_id                                            address  \
# 48   L705  907 SAN RAMON VALLEY BLVD 102, DANVILLE, CA 94526
# 67   L704     2305 CAMINO RAMON STE 110, SAN RAMON, CA 94583
#
#                    location  zipcode
# 48  37.7754429,-121.9669886    94526
# 67  37.7754429,-121.9669886    94583

# %%
# salvando e exportando base transformada

df_geocode.to_csv('../bases_finais/final_df_geocode.csv', sep=';', index=False)
