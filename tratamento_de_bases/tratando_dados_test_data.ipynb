# %%
# Importando test_data

import pandas as pd

test_data = pd.read_csv('../bases_iniciais/test_data.csv')

test_data
# Out:
#        CodItem                                          Desc Item Category  \
# 0     70003237  MAGNESIO, SORO (EXEMPLO DE EXPRESSAO DE RESULT...       CA
# 1     70000638                    HEMOGRAMA, AUTOMATIZADO, SANGUE       CA
# 2     70001597                                    FERRITINA, SORO       CA
# 3     70000103  FERRO, DOSAGEM, SORO (EXEMPLO DE EXPRESSAO DE ...       CA
# 4     70000224  CALCIO, DOSAGEM, SORO (EXEMPLO DE EXPRESSAO DE...       CA
# ...        ...                                                ...      ...
# 1997  70008635                  GENES BRCA1 E BRCA2, MLPA, SANGUE       CA
# 1998  70005303  OBSTETRICA 1§ TRIMESTRE (ENDOVAGINAL), SEGUNDO...      RID
# 1999  70006441  HEMOFILIA A, ANALISE DO DNA, SEQUENCIAMENTO, S...       CA
# 2000  70004141                    INSULINA, SORO, 90 MIN APOS XXX       CA
# 2001  70001506                    INSULINA, SORO, 30 MIN APOS XXX       CA
#
#           Family        Speciality  Testing Cost
# ...

# %%
# trocando nomes para padrão python 

test_data = test_data.rename(columns = {'CodItem':'cod_item', 'Desc Item':'desc_item', 'Category':'category', 'Family': 'family', 'Speciality':'speciality', 'Testing Cost':'testing_cost'})
test_data
# Out:
#       cod_item                                          desc_item category  \
# 0     70003237  MAGNESIO, SORO (EXEMPLO DE EXPRESSAO DE RESULT...       CA
# 1     70000638                    HEMOGRAMA, AUTOMATIZADO, SANGUE       CA
# 2     70001597                                    FERRITINA, SORO       CA
# 3     70000103  FERRO, DOSAGEM, SORO (EXEMPLO DE EXPRESSAO DE ...       CA
# 4     70000224  CALCIO, DOSAGEM, SORO (EXEMPLO DE EXPRESSAO DE...       CA
# ...        ...                                                ...      ...
# 1997  70008635                  GENES BRCA1 E BRCA2, MLPA, SANGUE       CA
# 1998  70005303  OBSTETRICA 1§ TRIMESTRE (ENDOVAGINAL), SEGUNDO...      RID
# 1999  70006441  HEMOFILIA A, ANALISE DO DNA, SEQUENCIAMENTO, S...       CA
# 2000  70004141                    INSULINA, SORO, 90 MIN APOS XXX       CA
# 2001  70001506                    INSULINA, SORO, 30 MIN APOS XXX       CA
#
#           family        speciality  testing_cost
# ...

# %%
# checando valores nulos

test_data.isna().sum()
# Out:
# cod_item        0
# desc_item       0
# category        0
# family          0
# speciality      0
# testing_cost    0
# dtype: int64

# %%
# checando valores duplicados

test_data.duplicated().sum()
# Out:
# 0

# %%
# só para ter certeza

test_data['cod_item'].duplicated().sum()
# Out:
# 1

# %%
# checando dado com valor duplicado

test_data[test_data['cod_item'].duplicated()]
# Out:
#       cod_item                                          desc_item  \
# 1968  70004701  PROCEDIMENTO DIAGNOSTICO EM PAINEL DE IMUNOIST...
#
#                                       category   family            speciality  \
# 1968  PA                                        ANATOMO  IMMUNOHISTOCHEMISTRY
#
#       testing_cost
# 1968        362.96

# %%
# conferindo linhas duplicadas

test_data[test_data['cod_item'] == 70004701]
# Out:
#       cod_item                                          desc_item  \
# 1208  70004701  PROCEDIMENTO DIAGNOSTICO EM PAINEL DE IMUNOIST...
# 1968  70004701  PROCEDIMENTO DIAGNOSTICO EM PAINEL DE IMUNOIST...
#
#                                       category   family            speciality  \
# 1208                                        PA  ANATOMO  IMMUNOHISTOCHEMISTRY
# 1968  PA                                        ANATOMO  IMMUNOHISTOCHEMISTRY
#
#       testing_cost
# 1208        362.96
# 1968        362.96

# %%
# deletando repetição

test_data = test_data.drop(index=1968)
test_data
# Out:
#       cod_item                                          desc_item category  \
# 0     70003237  MAGNESIO, SORO (EXEMPLO DE EXPRESSAO DE RESULT...       CA
# 1     70000638                    HEMOGRAMA, AUTOMATIZADO, SANGUE       CA
# 2     70001597                                    FERRITINA, SORO       CA
# 3     70000103  FERRO, DOSAGEM, SORO (EXEMPLO DE EXPRESSAO DE ...       CA
# 4     70000224  CALCIO, DOSAGEM, SORO (EXEMPLO DE EXPRESSAO DE...       CA
# ...        ...                                                ...      ...
# 1997  70008635                  GENES BRCA1 E BRCA2, MLPA, SANGUE       CA
# 1998  70005303  OBSTETRICA 1§ TRIMESTRE (ENDOVAGINAL), SEGUNDO...      RID
# 1999  70006441  HEMOFILIA A, ANALISE DO DNA, SEQUENCIAMENTO, S...       CA
# 2000  70004141                    INSULINA, SORO, 90 MIN APOS XXX       CA
# 2001  70001506                    INSULINA, SORO, 30 MIN APOS XXX       CA
#
#           family        speciality  testing_cost
# ...

# %%
# resetando index

test_data.reset_index(inplace=True, drop=True)
test_data
# Out:
#       cod_item                                          desc_item category  \
# 0     70003237  MAGNESIO, SORO (EXEMPLO DE EXPRESSAO DE RESULT...       CA
# 1     70000638                    HEMOGRAMA, AUTOMATIZADO, SANGUE       CA
# 2     70001597                                    FERRITINA, SORO       CA
# 3     70000103  FERRO, DOSAGEM, SORO (EXEMPLO DE EXPRESSAO DE ...       CA
# 4     70000224  CALCIO, DOSAGEM, SORO (EXEMPLO DE EXPRESSAO DE...       CA
# ...        ...                                                ...      ...
# 1996  70008635                  GENES BRCA1 E BRCA2, MLPA, SANGUE       CA
# 1997  70005303  OBSTETRICA 1§ TRIMESTRE (ENDOVAGINAL), SEGUNDO...      RID
# 1998  70006441  HEMOFILIA A, ANALISE DO DNA, SEQUENCIAMENTO, S...       CA
# 1999  70004141                    INSULINA, SORO, 90 MIN APOS XXX       CA
# 2000  70001506                    INSULINA, SORO, 30 MIN APOS XXX       CA
#
#           family        speciality  testing_cost
# ...

# %%
test_data.describe(include='all')
# Out:
#             cod_item                              desc_item category   family  \
# count   2.001000e+03                                   2001     2001     2001
# unique           NaN                                   1997        6       23
# top              NaN  PLAQUETAS, ANTICORPOS IGG E IGM, SORO       CA  CORELAB
# freq             NaN                                      2     1578      990
# mean    7.000366e+07                                    NaN      NaN      NaN
# std     2.266616e+03                                    NaN      NaN      NaN
# min     7.000004e+07                                    NaN      NaN      NaN
# 25%     7.000166e+07                                    NaN      NaN      NaN
# 50%     7.000358e+07                                    NaN      NaN      NaN
# 75%     7.000534e+07                                    NaN      NaN      NaN
# max     7.000900e+07                                    NaN      NaN      NaN
#
# ...

# %%
# salvando e exportando base transformada

test_data.to_csv('./final_test_data.csv', sep=';', index=False)
