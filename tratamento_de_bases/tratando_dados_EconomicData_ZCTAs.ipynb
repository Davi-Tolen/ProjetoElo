# %%
# Importando EconomicData_ZCTAs

import pandas as pd
import numpy as np

EconomicData_ZCTAs = pd.read_csv('../bases_iniciais/EconomicData_ZCTAs.csv')
EconomicData_ZCTAs
# Out:
#         Unnamed: 0              id Geographic Area Name  \
# 0                0  8600000US35004          ZCTA5 35004
# 1                1  8600000US35005          ZCTA5 35005
# 2                2  8600000US35006          ZCTA5 35006
# 3                3  8600000US35007          ZCTA5 35007
# 4                4  8600000US35010          ZCTA5 35010
# ...            ...             ...                  ...
# 629275      629275  8600000US00979          ZCTA5 00979
# 629276      629276  8600000US00982          ZCTA5 00982
# 629277      629277  8600000US00983          ZCTA5 00983
# 629278      629278  8600000US00985          ZCTA5 00985
# 629279      629279  8600000US00987          ZCTA5 00987
#
#         TotalHouseholds_LessThan$10.000  TotalHouseholds_$10.000to$14.999  \
# 0                                   198                                71
# 1                                   188                               184
# ...

# %%
# Deletando coluna "Unnamed: 0"

EconomicData_ZCTAs = EconomicData_ZCTAs.drop(columns=['Unnamed: 0'])
EconomicData_ZCTAs
# Out:
#                     id Geographic Area Name  TotalHouseholds_LessThan$10.000  \
# 0       8600000US35004          ZCTA5 35004                              198
# 1       8600000US35005          ZCTA5 35005                              188
# 2       8600000US35006          ZCTA5 35006                               71
# 3       8600000US35007          ZCTA5 35007                              396
# 4       8600000US35010          ZCTA5 35010                              700
# ...                ...                  ...                              ...
# 629275  8600000US00979          ZCTA5 00979                              735
# 629276  8600000US00982          ZCTA5 00982                             1299
# 629277  8600000US00983          ZCTA5 00983                             2638
# 629278  8600000US00985          ZCTA5 00985                             2426
# 629279  8600000US00987          ZCTA5 00987                             3330
#
# ...

# %%
# checando valores nulos

EconomicData_ZCTAs.isna().sum()
# Out:
# id                                    0
# Geographic Area Name                  0
# TotalHouseholds_LessThan$10.000       0
# TotalHouseholds_$10.000to$14.999      0
# TotalHouseholds_$15.000to$24.999      0
# TotalHouseholds_$25.000to$34.999      0
# TotalHouseholds_$35.000to$49.999      0
# TotalHouseholds_$50.000to$74.999      0
# TotalHouseholds_$75.000to$99.999      0
# TotalHouseholds_$100.000to$149.999    0
# TotalHouseholds_$150.000to$199.999    0
# TotalHouseholds_$200.000OrMore        0
# dtype: int64

# %%
# checando valores duplicados

EconomicData_ZCTAs['id'].duplicated().sum()
# Out:
# 596160

# %%
# checando dado com valor duplicado

EconomicData_ZCTAs[EconomicData_ZCTAs['id'].duplicated()]
# Out:
#                     id Geographic Area Name  TotalHouseholds_LessThan$10.000  \
# 33120   8600000US35004          ZCTA5 35004                              198
# 33121   8600000US35005          ZCTA5 35005                              188
# 33122   8600000US35006          ZCTA5 35006                               71
# 33123   8600000US35007          ZCTA5 35007                              396
# 33124   8600000US35010          ZCTA5 35010                              700
# ...                ...                  ...                              ...
# 629275  8600000US00979          ZCTA5 00979                              735
# 629276  8600000US00982          ZCTA5 00982                             1299
# 629277  8600000US00983          ZCTA5 00983                             2638
# 629278  8600000US00985          ZCTA5 00985                             2426
# 629279  8600000US00987          ZCTA5 00987                             3330
#
# ...

# %%
# conferindo linhas duplicadas

EconomicData_ZCTAs[EconomicData_ZCTAs['id'] == '8600000US35004']
# Out:
#                     id Geographic Area Name  TotalHouseholds_LessThan$10.000  \
# 0       8600000US35004          ZCTA5 35004                              198
# 33120   8600000US35004          ZCTA5 35004                              198
# 66240   8600000US35004          ZCTA5 35004                              198
# 99360   8600000US35004          ZCTA5 35004                              198
# 132480  8600000US35004          ZCTA5 35004                              198
# 165600  8600000US35004          ZCTA5 35004                              198
# 198720  8600000US35004          ZCTA5 35004                              198
# 231840  8600000US35004          ZCTA5 35004                              198
# 264960  8600000US35004          ZCTA5 35004                              198
# 298080  8600000US35004          ZCTA5 35004                              198
# 331200  8600000US35004          ZCTA5 35004                              198
# ...

# %%
# removendo linhas completamente duplicadas

EconomicData_ZCTAs = EconomicData_ZCTAs.drop_duplicates()

# %%
# conferindo 

EconomicData_ZCTAs[EconomicData_ZCTAs['id'] == '8600000US35004']
# Out:
#                id Geographic Area Name  TotalHouseholds_LessThan$10.000  \
# 0  8600000US35004          ZCTA5 35004                              198
#
#    TotalHouseholds_$10.000to$14.999  TotalHouseholds_$15.000to$24.999  \
# 0                                71                               298
#
#    TotalHouseholds_$25.000to$34.999  TotalHouseholds_$35.000to$49.999  \
# 0                               513                               647
#
#    TotalHouseholds_$50.000to$74.999  TotalHouseholds_$75.000to$99.999  \
# 0                              1117                               529
#
#    TotalHouseholds_$100.000to$149.999  TotalHouseholds_$150.000to$199.999  \
# 0                                 945                                 245
#
#    TotalHouseholds_$200.000OrMore
# 0                              61

# %%
EconomicData_ZCTAs
# Out:
#                    id Geographic Area Name  TotalHouseholds_LessThan$10.000  \
# 0      8600000US35004          ZCTA5 35004                              198
# 1      8600000US35005          ZCTA5 35005                              188
# 2      8600000US35006          ZCTA5 35006                               71
# 3      8600000US35007          ZCTA5 35007                              396
# 4      8600000US35010          ZCTA5 35010                              700
# ...               ...                  ...                              ...
# 33115  8600000US00979          ZCTA5 00979                              735
# 33116  8600000US00982          ZCTA5 00982                             1299
# 33117  8600000US00983          ZCTA5 00983                             2638
# 33118  8600000US00985          ZCTA5 00985                             2426
# 33119  8600000US00987          ZCTA5 00987                             3330
#
# ...

# %%
# checando se ainda existem repetições

EconomicData_ZCTAs['id'].duplicated().sum()
# Out:
# 0

# %%
# tornando nomes como padrão python

EconomicData_ZCTAs = EconomicData_ZCTAs.rename(columns = {'Geographic Area Name':'zipcode'})
EconomicData_ZCTAs
# Out:
#                    id      zipcode  TotalHouseholds_LessThan$10.000  \
# 0      8600000US35004  ZCTA5 35004                              198
# 1      8600000US35005  ZCTA5 35005                              188
# 2      8600000US35006  ZCTA5 35006                               71
# 3      8600000US35007  ZCTA5 35007                              396
# 4      8600000US35010  ZCTA5 35010                              700
# ...               ...          ...                              ...
# 33115  8600000US00979  ZCTA5 00979                              735
# 33116  8600000US00982  ZCTA5 00982                             1299
# 33117  8600000US00983  ZCTA5 00983                             2638
# 33118  8600000US00985  ZCTA5 00985                             2426
# 33119  8600000US00987  ZCTA5 00987                             3330
#
#        TotalHouseholds_$10.000to$14.999  TotalHouseholds_$15.000to$24.999  \
# 0                                    71                               298
# ...

# %%
# avaliando incoerências

EconomicData_ZCTAs.describe(include='all')
# Out:
#                     id      zipcode  TotalHouseholds_LessThan$10.000  \
# count            33120        33120                     33120.000000
# unique           33120        33120                              NaN
# top     8600000US35004  ZCTA5 35004                              NaN
# freq                 1            1                              NaN
# mean               NaN          NaN                       230.234903
# std                NaN          NaN                       441.473859
# min                NaN          NaN                         0.000000
# 25%                NaN          NaN                        11.000000
# 50%                NaN          NaN                        55.000000
# 75%                NaN          NaN                       257.000000
# max                NaN          NaN                      7901.000000
#
#         TotalHouseholds_$10.000to$14.999  TotalHouseholds_$15.000to$24.999  \
# ...

# %%
# salvando e exportando base transformada

EconomicData_ZCTAs.to_csv('../bases_finais/final_EconomicData_ZCTAs.csv', sep=';', index=False)
