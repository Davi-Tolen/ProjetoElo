# %%
# Importando DemographicData_ZCTAs

import pandas as pd
import numpy as np

DemographicData_ZCTAs = pd.read_csv('../bases_iniciais/DemographicData_ZCTAs.csv')
DemographicData_ZCTAs
# Out:
#        Unnamed: 0              Id GeographicAreaName  TotalPopulation  \
# 0               0  8600000US35004        ZCTA5 35004            12045
# 1               1  8600000US35005        ZCTA5 35005             7344
# 2               2  8600000US35006        ZCTA5 35006             2883
# 3               3  8600000US35007        ZCTA5 35007            26332
# 4               4  8600000US35010        ZCTA5 35010            20613
# ...           ...             ...                ...              ...
# 33115       33115  8600000US00979        ZCTA5 00979            16130
# 33116       33116  8600000US00982        ZCTA5 00982            14346
# 33117       33117  8600000US00983        ZCTA5 00983            33947
# 33118       33118  8600000US00985        ZCTA5 00985            31682
# 33119       33119  8600000US00987        ZCTA5 00987            54241
#
#        SexRatio(males per 100 females)  Population_Under5Years  \
# ...

# %%
DemographicData_ZCTAs.describe()
# Out:
#          Unnamed: 0  TotalPopulation  SexRatio(males per 100 females)  \
# count  33120.000000     33120.000000                     32620.000000
# mean   16559.500000      9903.343961                       116.842275
# std     9561.064794     14714.043400                      1483.160382
# min        0.000000         0.000000                         0.500000
# 25%     8279.750000       705.750000                        91.300000
# 50%    16559.500000      2801.000000                        98.400000
# 75%    24839.250000     13475.250000                       107.900000
# max    33119.000000    128294.000000                    265600.000000
#
#        Population_Under5Years  Population_5to9Years  Population_10to14Years  \
# count            33120.000000          33120.000000            33120.000000
# mean               601.164674            613.889312              637.866304
# std                995.953840            995.199535             1025.828850
# ...

# %%
# Deletando coluna "Unnamed: 0"

DemographicData_ZCTAs = DemographicData_ZCTAs.drop(columns=['Unnamed: 0'])
DemographicData_ZCTAs
# Out:
#                    Id GeographicAreaName  TotalPopulation  \
# 0      8600000US35004        ZCTA5 35004            12045
# 1      8600000US35005        ZCTA5 35005             7344
# 2      8600000US35006        ZCTA5 35006             2883
# 3      8600000US35007        ZCTA5 35007            26332
# 4      8600000US35010        ZCTA5 35010            20613
# ...               ...                ...              ...
# 33115  8600000US00979        ZCTA5 00979            16130
# 33116  8600000US00982        ZCTA5 00982            14346
# 33117  8600000US00983        ZCTA5 00983            33947
# 33118  8600000US00985        ZCTA5 00985            31682
# 33119  8600000US00987        ZCTA5 00987            54241
#
#        SexRatio(males per 100 females)  Population_Under5Years  \
# 0                                 94.1                     805
# 1                                 86.1                     504
# 2                                108.2                      96
# ...

# %%
# checando valores nulos

DemographicData_ZCTAs.isna().sum()
# Out:
# Id                                   0
# GeographicAreaName                   0
# TotalPopulation                      0
# SexRatio(males per 100 females)    500
# Population_Under5Years               0
# Population_5to9Years                 0
# Population_10to14Years               0
# Population_15to19Years               0
# Population_20to24Years               0
# Population_25to34Years               0
# Population_35to44Years               0
# Population_45to54Years               0
# Population_55to59Years               0
# Population_60to64Years               0
# Population_65to74Years               0
# Population_75to84Years               0
# Population_85YearsAndOver            0
# MedianAgeInYears                   569
# dtype: int64

# %%
DemographicData_ZCTAs[DemographicData_ZCTAs['SexRatio(males per 100 females)'].isna()]
# Out:
#                    Id GeographicAreaName  TotalPopulation  \
# 5      8600000US35013        ZCTA5 35013               46
# 47     8600000US35082        ZCTA5 35082                0
# 142    8600000US35457        ZCTA5 35457                0
# 403    8600000US36267        ZCTA5 36267                7
# 539    8600000US36590        ZCTA5 36590                0
# ...               ...                ...              ...
# 32920  8600000US82715        ZCTA5 82715                0
# 32955  8600000US82936        ZCTA5 82936                0
# 32981  8600000US83121        ZCTA5 83121                0
# 33099  8600000US00950        ZCTA5 00950                0
# 33100  8600000US00951        ZCTA5 00951                0
#
#        SexRatio(males per 100 females)  Population_Under5Years  \
# 5                                  NaN                       0
# 47                                 NaN                       0
# 142                                NaN                       0
# ...

# %%
# dados com valores irrelevantes, faz mais sentido deletar as linhas

DemographicData_ZCTAs = DemographicData_ZCTAs.dropna()
DemographicData_ZCTAs
# Out:
#                    Id GeographicAreaName  TotalPopulation  \
# 0      8600000US35004        ZCTA5 35004            12045
# 1      8600000US35005        ZCTA5 35005             7344
# 2      8600000US35006        ZCTA5 35006             2883
# 3      8600000US35007        ZCTA5 35007            26332
# 4      8600000US35010        ZCTA5 35010            20613
# ...               ...                ...              ...
# 33115  8600000US00979        ZCTA5 00979            16130
# 33116  8600000US00982        ZCTA5 00982            14346
# 33117  8600000US00983        ZCTA5 00983            33947
# 33118  8600000US00985        ZCTA5 00985            31682
# 33119  8600000US00987        ZCTA5 00987            54241
#
#        SexRatio(males per 100 females)  Population_Under5Years  \
# 0                                 94.1                     805
# 1                                 86.1                     504
# 2                                108.2                      96
# ...

# %%
# resetando index

DemographicData_ZCTAs.reset_index(inplace=True, drop=True)
DemographicData_ZCTAs
# Out:
#                    Id GeographicAreaName  TotalPopulation  \
# 0      8600000US35004        ZCTA5 35004            12045
# 1      8600000US35005        ZCTA5 35005             7344
# 2      8600000US35006        ZCTA5 35006             2883
# 3      8600000US35007        ZCTA5 35007            26332
# 4      8600000US35010        ZCTA5 35010            20613
# ...               ...                ...              ...
# 32498  8600000US00979        ZCTA5 00979            16130
# 32499  8600000US00982        ZCTA5 00982            14346
# 32500  8600000US00983        ZCTA5 00983            33947
# 32501  8600000US00985        ZCTA5 00985            31682
# 32502  8600000US00987        ZCTA5 00987            54241
#
#        SexRatio(males per 100 females)  Population_Under5Years  \
# 0                                 94.1                     805
# 1                                 86.1                     504
# 2                                108.2                      96
# ...

# %%
# checando se os valores nulos foram deletados

DemographicData_ZCTAs.isna().sum()
# Out:
# Id                                 0
# GeographicAreaName                 0
# TotalPopulation                    0
# SexRatio(males per 100 females)    0
# Population_Under5Years             0
# Population_5to9Years               0
# Population_10to14Years             0
# Population_15to19Years             0
# Population_20to24Years             0
# Population_25to34Years             0
# Population_35to44Years             0
# Population_45to54Years             0
# Population_55to59Years             0
# Population_60to64Years             0
# Population_65to74Years             0
# Population_75to84Years             0
# Population_85YearsAndOver          0
# MedianAgeInYears                   0
# dtype: int64

# %%
# checando valores duplicados

DemographicData_ZCTAs.duplicated().sum()
# Out:
# 0

# %%
# conferindo

DemographicData_ZCTAs['Id'].duplicated().sum()
# Out:
# 0

# %%
# tornando nomes como padrão python

DemographicData_ZCTAs = DemographicData_ZCTAs.rename(columns = {'Id':'id', 'GeographicAreaName':'zipcode', 'TotalPopulation': 'total_population' })
DemographicData_ZCTAs
# Out:
#                    id      zipcode  total_population  \
# 0      8600000US35004  ZCTA5 35004             12045
# 1      8600000US35005  ZCTA5 35005              7344
# 2      8600000US35006  ZCTA5 35006              2883
# 3      8600000US35007  ZCTA5 35007             26332
# 4      8600000US35010  ZCTA5 35010             20613
# ...               ...          ...               ...
# 32498  8600000US00979  ZCTA5 00979             16130
# 32499  8600000US00982  ZCTA5 00982             14346
# 32500  8600000US00983  ZCTA5 00983             33947
# 32501  8600000US00985  ZCTA5 00985             31682
# 32502  8600000US00987  ZCTA5 00987             54241
#
#        SexRatio(males per 100 females)  Population_Under5Years  \
# 0                                 94.1                     805
# 1                                 86.1                     504
# 2                                108.2                      96
# 3                                 95.0                    1936
# ...

# %%
# salvando e exportando base transformada

DemographicData_ZCTAs.to_csv('../bases_finais/final_DemographicData_ZCTAs.csv', sep=';', index=False)
